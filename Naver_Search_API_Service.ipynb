# %% [markdown]
# <a href="https://colab.research.google.com/github/hyuntaedo/Data_Analysis/blob/main/Naver_Search_API_Service.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 네이버 검색 API 서비스

# %% [markdown]
# ## 네이버 웹문서 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "QQQMTZWTl814mtwg6jEy"
client_secret = "scmqx0roYi"

query = urllib.parse.quote(input("검색질의 : "))
idx = 0
display = 100
start = 1
end = 1000

web_df = pd.DataFrame(columns=('Title','Link','Description'))
for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/webkr?query=" + query \
    +"&display=" + str(display) \
    +"&start=" + str(start_index) 

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            web_df.loc[idx] = [title,link,description]
            idx += 1
    else:
        print("Error Code:" + rescode)
web_df
# Out:
# 검색질의 : 컴퓨터
#                                        Title  ...                                        Description
# 0                                 컴퓨터 - 나무위키  ...  [4] 대형 컴퓨터와 개인용 컴퓨터(데스크톱 컴퓨터, 노트북 컴퓨터, 태블릿 컴퓨터...
# 1                    좋은 컴퓨터를 만드는 사람들 - 한성컴퓨터  ...                                   좋은 컴퓨터를 만드는 사람들!
# 2                                      오마이피씨  ...          조립컴퓨터 전문 쇼핑몰, 데스크탑, 게임용, 모니터, 컴퓨터부품 등 판매.
# 3                                     한글과컴퓨터  ...  한컴오피스, 씽크프리, 전자책, 앱북, 솔루션 제품 체험판, 뷰어 다운로드 및 고객...
# 4    컴퓨터게시판은 컴퓨터에 관한 정보 교류를 위한 곳입니다. - 오늘의유머  ...  컴퓨터 고수님 이정도 스펙이면 중고컴 얼마 정도 할까요?ㅎㅎ구글을 뒤져보니 초보를 ...
# ..                                       ...  ...                                                ...
# 145      컴퓨터에 휴대폰 동기화: 사용자 휴대폰 앱 | Microsoft  ...  휴대폰과 컴퓨터를 동기화하면 디바이스를 최대한 활용할 수 있습니다. 사용자 휴대폰 ...
# 146             컴퓨터 - 무료 다운로드 - silhouetteAC  ...          무료 컴퓨터 실루엣을 다운로드하세요. 최고의 무료 아이콘 실루엣과 이미지.
# 147          컴퓨터 400585 - 무료 다운로드 - illustAC  ...      무료 컴퓨터 이미지를 다운로드하세요. 최고의 무료 아이콘 벡터, 사진 및 이미지.
# 148                                   중고 컴퓨터  ...  LG컴퓨터 6세대 스카이레이크 i7 6700 32G SSD240G 500G [중고]...
# 149             컴퓨터 - 무료 다운로드 - silhouetteAC  ...          무료 컴퓨터 실루엣을 다운로드하세요. 최고의 무료 1 정 실루엣과 이미지.
#
# [150 rows x 3 columns]

# %% [markdown]
# ## 네이버 지식 iN 검색

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "QQQMTZWTl814mtwg6jEy"
client_secret = "scmqx0roYi"

query = urllib.parse.quote(input("검색질의 : "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'


kin_df = pd.DataFrame(columns=('Title','Link','Description'))
for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/kin?query=" + query \
    +"&display=" + str(display) \
    +"&start=" + str(start_index) \
    + "&sort" + sort 

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            kin_df.loc[idx] = [title,link,description]
            idx += 1
    else:
        print("Error Code:" + rescode)
kin_df
# Out:
# 검색질의 : 컴퓨터
#               Title  ...                                        Description
# 0       컴퓨터학원 상승할곳~  ...  컴퓨터학원 상승할곳 있을까요? 독학으로 하다보니 진도가 많이 느려서요..... 어떤...
# 1      컴퓨터배우기 쉬운 방법  ...  얼마전부터 컴퓨터 기초 관련 책을 한 권 구입해서 보고 있어요... 뭔가 컴퓨터배우...
# 2        재송동 컴퓨터 수리  ...  컴퓨터 cpu를 교체하고싶은데 재송2동 컴퓨터 수리 저렴한 곳 있을까요? 출장비 없...
# 3      웹에서 컴퓨터 사용하기  ...  ... 사지방 컴퓨터에서 할려니까 너무 답답합니다. 관리자... 있는 컴퓨터를 제공...
# 4    안녕하세요! 려독컴퓨터님!  ...  ... 제가 저희 엄마 한테 우리 컴퓨터가 오래된 컴퓨터라고 말을 해도, 좀처럼 말...
# ..              ...  ...                                                ...
# 995   컴퓨터 견적 문의 합니다  ...  컴퓨터 견적 문의할려고 합니다. 부모님꼐서 이번 중간고사 성적이 좋아서 일주일내로 ...
# 996     컴퓨터 사양 및 속도  ...  현재 쓰고있는 컴퓨터 그래픽카드가 지포스 680 입니다 나름오래쓴 컴퓨터인데 1. ...
# 997    컴퓨터 공학과 질문이요  ...  ... 인서울 컴퓨터 공학과에 진학하고 싶은데 질문을 좀... - 컴퓨터 공학과의 ...
# 998      컴퓨터사양알려주세요  ...  컴퓨터를 바꾸고싶은데요 가격은 80만원이하 정도생각하있고요 배틀필드 나 레인보우식스...
# 999  컴퓨터 견적 좀 부탁드려요  ...  ... 잘 컴퓨터에 대해 잘 모르고 일체형 컴퓨터를 써서 게임도 잘 안되고 간단한 ...
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## 네이버 블로그 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "QQQMTZWTl814mtwg6jEy"
client_secret = "scmqx0roYi"

query = urllib.parse.quote(input("검색질의 : "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'


blog_df = pd.DataFrame(columns=('Title','Link','Description',"Blogger Name","Blogger Link","Post Date"))
for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/blog?query=" + query \
    +"&display=" + str(display) \
    +"&start=" + str(start_index) \
    + "&sort" + sort 

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            blogger_name = items[item_index]['bloggername']
            blogger_link = items[item_index]['bloggerlink']
            post_date = items[item_index]['postdate']
            blog_df.loc[idx] = [title,link,description,blogger_name,blogger_link,post_date]
            idx += 1
    else:
        print("Error Code:" + rescode)
blog_df
# Out:
# 검색질의 : 컴퓨터
#                                 Title  ... Post Date
# 0                       컴퓨터학원 주저없는 선택  ...  20210612
# 1                 국비지원컴퓨터학원 지원요건 및 과정  ...  20210615
# 2                  부산컴퓨터학원 기초부터 튼튼하게!  ...  20210603
# 3                컴퓨터학원 단계적으로 습득하는 플랜!  ...  20210604
# 4           컴퓨터공학 평생교육원 통해 학위 취득 한 방법  ...  20210609
# ..                                ...  ...       ...
# 995  【에듀맥 학습 정보】 학습 속 컴퓨터 사용 장점 vs 단점  ...  20210501
# 996                   부평 작업용 조립컴퓨터 설치  ...  20210305
# 997           마북동 컴퓨터수리 모니터 연결 신호 없을때  ...  20210421
# 998     [강남컴퓨터학원] 컴활1급 합격 방법 공유합니다~!!  ...  20201230
# 999             컴퓨터 화면 캡쳐 단축키하나로 끝내기!  ...  20210414
#
# [1000 rows x 6 columns]

# %% [markdown]
# ## 네이버 책 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "QQQMTZWTl814mtwg6jEy"
client_secret = "scmqx0roYi"

query = urllib.parse.quote(input("검색질의 : "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'


book_df = pd.DataFrame(columns=('Title','Link','Image',"Author","Price","Discount","Publisher","ISBN","Description","Publication Date"))
for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/book?query=" + query \
    +"&display=" + str(display) \
    +"&start=" + str(start_index) \
    + "&sort" + sort 

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            author = items[item_index]['author']
            price = items[item_index]['price']
            discount = items[item_index]['discount']
            publisher = items[item_index]['publisher']
            isbn = items[item_index]['isbn']
            description = re.sub(remove_tag,'',items[item_index]['description'])
            pubdate = items[item_index]['pubdate']
            book_df.loc[idx] = [title,link,image,author,price,discount,publisher,isbn,description,pubdate]
            idx += 1
    else:
        print("Error Code:" + rescode)
book_df
# Out:
# 검색질의 : 컴퓨터
#                                                  Title  ... Publication Date
# 0    2021시나공 총정리 컴퓨터활용능력 1급 필기 (핵심요약 + 기출문제 + 모의고사 ...  ...         20201124
# 1    2021 시나공 컴퓨터활용능력 2급 실기 (컴활 함수 사전 + 자동 채점 프로그램 ...  ...         20201026
# 2    2021 시나공 컴퓨터활용능력 1급 실기 (컴활함수사전 + 자동 채점 프로그램 + ...  ...         20201026
# 3    컴퓨터활용능력 2급 필기(2021)(시나공) (필수암기집+동영상강의+암기프로그램+기...  ...         20200923
# 4    컴퓨터활용능력 1급 필기(2021)(시나공) (필수암기집+동영상강의+암기프로그램+기...  ...         20200923
# ..                                                 ...  ...              ...
# 995                                  데이터 통신 및 컴퓨터 네트워크  ...         20170303
# 996  시나공 기출문제집 컴퓨터활용능력 2급 필기 (핵심요약 128 + 기출문제 15회 +...  ...         20111121
# 997                     시나공 기출문제집 컴퓨터활용능력 1급 필기 (2012)  ...         20111121
# 998                                끝짱 컴퓨터 영재 만들기 STEP1  ...         20180123
# 999             컴퓨터활용능력1급 필기 (2007 시나공 써머리, 핵심요약+기출문제)  ...         20070120
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 영화 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "QQQMTZWTl814mtwg6jEy"
client_secret = "scmqx0roYi"

query = urllib.parse.quote(input("검색질의 : "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'


movie_df = pd.DataFrame(columns=('Title','Link','Image',"Subtitle","Publication Date","director","actor","User Rating"))
for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/movie?query=" + query \
    +"&display=" + str(display) \
    +"&start=" + str(start_index) \
    + "&sort" + sort 

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            subtitle = items[item_index]['subtitle']
            pub_date = items[item_index]['pubDate']
            director = items[item_index]['director']
            actor = items[item_index]['actor']
            user_rating = items[item_index]['userRating']
            movie_df.loc[idx] = [title, link, image, subtitle, pub_date, director, actor, user_rating]
            idx += 1
    else:
        print("Error Code:" + rescode)
movie_df
# Out:
# 검색질의 : 아이언맨
#                    Title  ... User Rating
# 0        일론 머스크: 리얼 아이언맨  ...        4.61
# 1                   아이언맨  ...        4.95
# 2     아이언맨 &amp; 캡틴 아메리카  ...        9.00
# 3                 아이언맨 3  ...        8.86
# 4    아이언 맨: 라이즈 오브 테크노보어  ...        3.28
# ..                   ...  ...         ...
# 125           인빈서블 아이언 맨  ...        7.24
# 126     특수공작원 아이언맨 - 시리즈  ...        7.63
# 127           특수공작원 아이언맨  ...        9.00
# 128                아이언 맨  ...        5.37
# 129                아이언 맨  ...        7.54
#
# [130 rows x 8 columns]

# %% [markdown]
# ## 네이버 쇼핑 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "QQQMTZWTl814mtwg6jEy"
client_secret = "scmqx0roYi"

query = urllib.parse.quote(input("검색질의 : "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'


shop_df = pd.DataFrame(columns=('Title','Link','Image',"Low Price","High Price","Mall Name","Product ID","Product Type","Maker","Brand"))
for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/shop?query=" + query \
    +"&display=" + str(display) \
    +"&start=" + str(start_index) \
    + "&sort" + sort 

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            image = items[item_index]['image']
            low_price = items[item_index]['lprice']
            high_price = items[item_index]['hprice']
            mall_name = items[item_index]['mallName']
            product_id = items[item_index]['productId']
            product_type = items[item_index]['productType']
            maker = items[item_index]['maker']
            brand = items[item_index]['brand']
            shop_df.loc[idx] = [title, link, image, low_price, high_price, mall_name, product_id, product_type,maker,brand]
            idx += 1
    else:
        print("Error Code:" + rescode)
shop_df
# Out:
# 검색질의 : 컴퓨터
#                                                  Title  ... Brand
# 0    프리미엄 게이밍 조립컴퓨터 RTX3060 Ti 배틀그라운드 오버워치 배그 본체 사무...  ...  마루PC
# 1                    아싸컴 프리미엄 게이밍 i5-9400F + 외장형 그래픽카드  ...   아싸컴
# 2                                    LG전자 27V70N-FR50K  ...  LG전자
# 3                               삼성전자 삼성 DM530ADA-L15AW  ...    삼성
# 4       게이밍컴퓨터 조립PC 배틀그라운드 서든어택 롤 오버워치 피파온라인4 로스트아크컴퓨터  ...
# ..                                                 ...  ...   ...
# 995  프리미엄 조립식컴퓨터 SSD 사무용 게임용 i3 i5 i7 조립PC 롤 피파4 오버...  ...
# 996  조립 게이밍 컴퓨터 인텔 코어i5-7세대 7500 GTX1060 배틀그라운드 오버워...  ...
# 997                 전주 익산 군산 정읍 조립컴퓨터 게이밍팩토리 조립PC 월간견적  ...
# 998                                    HP S01-PF1005KL  ...    HP
# 999                             삼성전자 삼성 DM500TCA-A78AB  ...    삼성
#
# [1000 rows x 10 columns]

# %% [markdown]
# ## 네이버 뉴스 검색 API

# %%
import os
import sys
import urllib.request
import pandas as pd
import json
import re

client_id = "QQQMTZWTl814mtwg6jEy"
client_secret = "scmqx0roYi"

query = urllib.parse.quote(input("검색질의 : "))
idx = 0
display = 100
start = 1
end = 1000
sort = 'sim'


news_df = pd.DataFrame(columns=('Title',"Original Link",'Link','Description',"Publication Date"))
for start_index in range(start,end,display):

    url = "https://openapi.naver.com/v1/search/news?query=" + query \
    +"&display=" + str(display) \
    +"&start=" + str(start_index) \
    + "&sort" + sort 

    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        response_dict = json.loads(response_body.decode('utf-8'))
        items = response_dict['items']
        for item_index in range(0,len(items)):
            remove_tag = re.compile('<.*?>')
            title = re.sub(remove_tag,'',items[item_index]['title'])
            link = items[item_index]['link']
            original_link = items[item_index]['originallink']
            description = items[item_index]['description']
            pub_date = items[item_index]['pubDate']
            news_df.loc[idx] = [title, link, original_link,description,pub_date]
            idx += 1
    else:
        print("Error Code:" + rescode)
news_df
# Out:
# 검색질의 : 컴퓨터
#                                                  Title  ...                 Publication Date
# 0                              농관원, 가짜 친환경인증 농식품 집중 단속  ...  Wed, 16 Jun 2021 13:08:00 +0900
# 1    [더벨][thebell interview]&quot;영상진단 업계 게임체인저 꿈꾼다...  ...  Wed, 16 Jun 2021 13:06:00 +0900
# 2                     폴짝폴짝 '건강한 돌봄놀이터'…아동비만 예방에 효과 나타나  ...  Wed, 16 Jun 2021 13:02:00 +0900
# 3        [우리동네 힐링명소│서울 영등포구 '대림도서관'] 딱딱한 도서관, 말랑말랑한...  ...  Wed, 16 Jun 2021 12:58:00 +0900
# 4                           엔비디아, AGX 자비에 인더스트리얼 모듈 발표  ...  Wed, 16 Jun 2021 12:58:00 +0900
# ..                                                 ...  ...                              ...
# 995              아이들에게 교실을 돌려주려면? ‘학급당 적정 학생 수’에 답이 있다  ...  Mon, 14 Jun 2021 06:40:00 +0900
# 996                       강남세브란스, 새로운 하이브리드 스텐트그라프트 장착  ...  Mon, 14 Jun 2021 06:16:00 +0900
# 997                                 이준석 대표의 끝은 불평등 심화?  ...  Mon, 14 Jun 2021 06:10:00 +0900
# 998                      공공디자인 종합정보시스템 확대개편…반응형 웹기술 적용  ...  Mon, 14 Jun 2021 06:06:00 +0900
# 999                 포도 껍질 속 터지는 과육...기계 속 윤활유와 다르지 않더라  ...  Mon, 14 Jun 2021 06:03:00 +0900
#
# [1000 rows x 5 columns]
