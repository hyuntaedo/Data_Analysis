# %% [markdown]
# <a href="https://colab.research.google.com/github/hyuntaedo/Data_Analysis/blob/main/Website_Rank_Scrapping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 웹사이트 순위 스크래핑

# %% [markdown]
# ### 글로벌 웹사이트 순위

# %%
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

# %%
ㅡ

# %%
url = 'https://www.alexa.com/topsites'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url,'html.parser')
rank_df = pd.DataFrame(columns=("Rank","Site","Daily Time on Site","Daily Previous per Visitor","% of Traffic From Search","Total sites Linking In"))

sites = soup.find_all('div',{"class":"tr site-listing"})
for site in sites:
    rank = site.find('div',{"class":"td"}).get_text()
    website = site.select('p > a')[0].get_text()
    infos = site.find_all('div',{"class":"td right"})
    time = infos[0].get_text()
    pageview = infos[1].get_text() 
    traffic =  infos[2].get_text()
    linking =  infos[3].get_text()
    rank_df.loc[rank] = [rank,website,time,pageview,traffic,linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total sites Linking In
# 1     1           Google.com  ...                    0.30%              1,300,441
# 2     2          Youtube.com  ...                   13.80%                988,820
# 3     3            Tmall.com  ...                    1.10%                  6,212
# 4     4               Qq.com  ...                    3.00%                262,198
# 5     5            Baidu.com  ...                    7.20%                101,279
# 6     6             Sohu.com  ...                    2.10%                 25,945
# 7     7         Facebook.com  ...                    8.90%              2,181,031
# 8     8           Taobao.com  ...                    4.20%                 24,826
# 9     9               360.cn  ...                    0.40%                 14,998
# 10   10               Jd.com  ...                    1.70%                  8,481
# 11   11            Yahoo.com  ...                    8.90%                319,186
# 12   12           Amazon.com  ...                   19.60%                363,277
# 13   13        Wikipedia.org  ...                   74.70%                763,999
# 14   14            Weibo.com  ...                    2.20%                 68,824
# 15   15          Sina.com.cn  ...                    3.30%                 45,672
# 16   16              Zoom.us  ...                   14.80%                  3,009
# 17   17        Xinhuanet.com  ...                    2.70%                 34,113
# 18   18             Live.com  ...                    9.70%                 43,223
# 19   19           Reddit.com  ...                   37.10%                163,041
# 20   20          Netflix.com  ...                    9.40%                 10,865
# 21   21        Microsoft.com  ...                   27.60%                235,680
# 22   22           Office.com  ...                    6.30%                  5,767
# 23   23             Panda.tv  ...                    0.60%                    340
# 24   24            Zhanqi.tv  ...                    0.80%                    334
# 25   25        Instagram.com  ...                   14.80%                622,099
# 26   26        Google.com.hk  ...                    2.80%                  9,758
# 27   27           Alipay.com  ...                    1.50%                  3,513
# 28   28             Csdn.net  ...                    9.50%                  6,438
# 29   29               Vk.com  ...                    9.30%                124,054
# 30   30             Bing.com  ...                    5.40%                 41,693
# 31   31        Myshopify.com  ...                    3.10%                    118
# 32   32          Yahoo.co.jp  ...                   14.40%                 57,560
# 33   33  Microsoftonline.com  ...                    2.70%                    677
# 34   34        Bongacams.com  ...                    7.00%                178,712
# 35   35            Naver.com  ...                   10.30%                 38,994
# 36   36            Twitch.tv  ...                    7.30%                  9,771
# 37   37          Okezone.com  ...                    6.40%                 10,399
# 38   38          Twitter.com  ...                   11.70%              1,578,393
# 39   39             Ebay.com  ...                   18.00%                 74,970
# 40   40            Adobe.com  ...                   22.00%                244,100
# 41   41          Huanqiu.com  ...                    1.20%                  6,324
# 42   42            Tianya.cn  ...                    0.70%                  5,200
# 43   43               Yy.com  ...                    0.90%                  2,120
# 44   44            Amazon.in  ...                   24.10%                  6,673
# 45   45       Aliexpress.com  ...                   15.40%                 18,807
# 46   46         Amazon.co.jp  ...                   19.50%                 48,782
# 47   47             17ok.com  ...                    0.70%                    368
# 48   48         Linkedin.com  ...                   14.50%                608,654
# 49   49            Canva.com  ...                   16.40%                  2,376
# 50   50       Chaturbate.com  ...                    8.60%                156,661
#
# [50 rows x 6 columns]

# %% [markdown]
# ### 미국 웹사이트 순위

# %%
url = 'https://www.alexa.com/topsites/countries/US'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url,'html.parser')
rank_df = pd.DataFrame(columns=("Rank","Site","Daily Time on Site","Daily Previous per Visitor","% of Traffic From Search","Total sites Linking In"))

sites = soup.find_all('div',{"class":"tr site-listing"})
for site in sites:
    rank = site.find('div',{"class":"td"}).get_text()
    website = site.select('p > a')[0].get_text()
    infos = site.find_all('div',{"class":"td right"})
    time = infos[0].get_text()
    pageview = infos[1].get_text() 
    traffic =  infos[2].get_text()
    linking =  infos[3].get_text()
    rank_df.loc[rank] = [rank,website,time,pageview,traffic,linking]

rank_df
# Out:
#    Rank                 Site  ... % of Traffic From Search Total sites Linking In
# 1     1           Google.com  ...                    0.30%              1,300,441
# 2     2          Youtube.com  ...                   13.80%                988,820
# 3     3           Amazon.com  ...                   19.60%                363,277
# 4     4            Yahoo.com  ...                    8.90%                319,186
# 5     5         Facebook.com  ...                    8.90%              2,181,031
# 6     6              Zoom.us  ...                   14.80%                  3,009
# 7     7           Reddit.com  ...                   37.10%                163,041
# 8     8        Wikipedia.org  ...                   74.70%                763,999
# 9     9             Bing.com  ...                    5.40%                 41,693
# 10   10        Myshopify.com  ...                    3.10%                    118
# 11   11           Office.com  ...                    6.30%                  5,767
# 12   12             Ebay.com  ...                   18.00%                 74,970
# 13   13            Chase.com  ...                    8.50%                  1,231
# 14   14             Live.com  ...                    9.70%                 43,223
# 15   15        Microsoft.com  ...                   27.60%                235,680
# 16   16            Force.com  ...                    2.60%                  3,221
# 17   17          Netflix.com  ...                    9.40%                 10,865
# 18   18        Instagram.com  ...                   14.80%                622,099
# 19   19           Zillow.com  ...                   31.80%                  9,152
# 20   20            Twitch.tv  ...                    7.30%                  9,771
# 21   21  Microsoftonline.com  ...                    2.70%                    677
# 22   22       Salesforce.com  ...                    6.40%                  4,649
# 23   23             Etsy.com  ...                   18.40%                101,832
# 24   24         Linkedin.com  ...                   14.50%                608,654
# 25   25          Walmart.com  ...                   26.80%                 18,141
# 26   26             Okta.com  ...                    2.90%                    255
# 27   27       Chaturbate.com  ...                    8.60%                156,661
# 28   28          Dropbox.com  ...                    8.50%                 22,306
# 29   29           Indeed.com  ...                   27.40%                  7,630
# 30   30           Intuit.com  ...                   13.60%                  6,363
# 31   31            Adobe.com  ...                   22.00%                244,100
# 32   32          Twitter.com  ...                   11.70%              1,578,393
# 33   33             Espn.com  ...                   13.80%                  9,008
# 34   34       Wellsfargo.com  ...                   10.50%                  2,218
# 35   35              Cnn.com  ...                   20.20%                114,281
# 36   36            Apple.com  ...                   36.80%                174,917
# 37   37          Nytimes.com  ...                   29.00%                163,756
# 38   38            Slack.com  ...                    5.00%                  1,374
# 39   39       Craigslist.org  ...                   21.90%                 14,958
# 40   40        Homedepot.com  ...                   42.90%                 11,948
# 41   41      Instructure.com  ...                    8.70%                  1,034
# 42   42             Hulu.com  ...                    9.90%                 11,245
# 43   43       Aliexpress.com  ...                   15.40%                 18,807
# 44   44            Canva.com  ...                   16.40%                  2,376
# 45   45              Msn.com  ...                    5.10%                 97,844
# 46   46       Capitalone.com  ...                   12.50%                  1,083
# 47   47            Tmall.com  ...                    1.10%                  6,212
# 48   48             Imdb.com  ...                   49.90%                137,215
# 49   49           Paypal.com  ...                    8.20%                 16,257
# 50   50        Amazonaws.com  ...                    6.80%                 55,828
#
# [50 rows x 6 columns]

# %% [markdown]
# ### 한국 웹사이트 순위

# %%
url = 'https://www.alexa.com/topsites/countries/KR'
search_url = urllib.request.urlopen(url).read()
soup = BeautifulSoup(search_url,'html.parser')
rank_df = pd.DataFrame(columns=("Rank","Site","Daily Time on Site","Daily Previous per Visitor","% of Traffic From Search","Total sites Linking In"))

sites = soup.find_all('div',{"class":"tr site-listing"})
for site in sites:
    rank = site.find('div',{"class":"td"}).get_text()
    website = site.select('p > a')[0].get_text()
    infos = site.find_all('div',{"class":"td right"})
    time = infos[0].get_text()
    pageview = infos[1].get_text() 
    traffic =  infos[2].get_text()
    linking =  infos[3].get_text()
    rank_df.loc[rank] = [rank,website,time,pageview,traffic,linking]

rank_df
# Out:
#    Rank               Site  ... % of Traffic From Search Total sites Linking In
# 1     1         Google.com  ...                    0.30%              1,300,441
# 2     2          Naver.com  ...                   10.30%                 38,994
# 3     3        Youtube.com  ...                   13.80%                988,820
# 4     4           Daum.net  ...                    4.30%                 15,145
# 5     5        Tistory.com  ...                   25.90%                 10,601
# 6     6          Kakao.com  ...                    7.20%                 11,869
# 7     7          Tmall.com  ...                    1.10%                  6,212
# 8     8        Coupang.com  ...                   12.30%                    392
# 9     9         Amazon.com  ...                   19.60%                363,277
# 10   10       Google.co.kr  ...                   12.30%                  6,241
# 11   11          Namu.wiki  ...                   18.80%                    104
# 12   12       Facebook.com  ...                    8.90%              2,181,031
# 13   13        Netflix.com  ...                    9.40%                 10,865
# 14   14           Sohu.com  ...                    2.10%                 25,945
# 15   15      Wikipedia.org  ...                   74.70%                763,999
# 16   16             Qq.com  ...                    3.00%                262,198
# 17   17         Taobao.com  ...                    4.20%                 24,826
# 18   18             360.cn  ...                    0.40%                 14,998
# 19   19             Jd.com  ...                    1.70%                  8,481
# 20   20      Microsoft.com  ...                   27.60%                235,680
# 21   21          Baidu.com  ...                    7.20%                101,279
# 22   22      Instagram.com  ...                   14.80%                622,099
# 23   23       Dcinside.com  ...                   21.10%                    735
# 24   24         11st.co.kr  ...                    3.00%                  1,203
# 25   25            Zoom.us  ...                   14.80%                  3,009
# 26   26          Yahoo.com  ...                    8.90%                319,186
# 27   27          Adobe.com  ...                   22.00%                244,100
# 28   28          Upbit.com  ...                    7.70%                    107
# 29   29          Donga.com  ...                   15.30%                  4,204
# 30   30         Office.com  ...                    6.30%                  5,767
# 31   31      Gmarket.co.kr  ...                   17.50%                  2,500
# 32   32         Chosun.com  ...                   26.90%                  7,512
# 33   33        Sina.com.cn  ...                    3.30%                 45,672
# 34   34           Bing.com  ...                    5.40%                 41,693
# 35   35           Nate.com  ...                    7.20%                  2,219
# 36   36          Twitch.tv  ...                    7.30%                  9,771
# 37   37         Danawa.com  ...                   30.60%                  1,285
# 38   38          Weibo.com  ...                    2.20%                 68,824
# 39   39        Fmkorea.com  ...                   15.60%                    795
# 40   40          Apple.com  ...                   36.80%                174,917
# 41   41           Ebay.com  ...                   18.00%                 74,970
# 42   42      Auction.co.kr  ...                   11.70%                  1,352
# 43   43  Stackoverflow.com  ...                   75.90%                 26,118
# 44   44      Afreecatv.com  ...                    8.00%                    495
# 45   45       Nicovideo.jp  ...                   12.60%                 12,317
# 46   46       Amazon.co.uk  ...                   14.40%                 56,938
# 47   47         Reddit.com  ...                   37.10%                163,041
# 48   48        Dropbox.com  ...                    8.50%                 22,306
# 49   49       Amazon.co.jp  ...                   19.50%                 48,782
# 50   50      Hometax.go.kr  ...                   23.20%                  2,018
#
# [50 rows x 6 columns]
